# %%
import os
import sys
sys.path.append(os.path.realpath('../..'))
import aoc
my_aoc = aoc.AdventOfCode(2019,6)
from solution import CelestialObject, load_objects, shortest_path

# %%
input_text="""COM)B
B)C
C)D
D)E
E)F
B)G
G)H
D)I
E)J
J)K
K)L"""

# %%
objects = load_objects(input_text.splitlines())
# orbit_count = objects['COM'].calc_orbits()
orbit_count = 0
for obj in objects.values():
    # orbit_count += obj.direct_orbits + obj.indirect_orbits
    orbit_count += obj.calc_orbits()
print(orbit_count)
# Out:
# 42

# %%
input_text = """COM)B
B)C
C)D
D)E
E)F
B)G
G)H
D)I
E)J
J)K
K)L
K)YOU
I)SAN"""

# %%
objects = load_objects(input_text.splitlines())
for obj in objects.values():
    obj.calc_orbits()

start = objects['YOU'].parent
end = objects['SAN'].parent

print(f"shortest_path: {shortest_path(start, end)}")
# Out:
# shortest_path: 4
