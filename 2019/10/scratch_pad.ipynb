# %%
import os
import sys
sys.path.append(os.path.realpath('../..'))
import aoc
my_aoc = aoc.AdventOfCode(2019,10)
from grid import Grid, linear_distance, sort_collinear_points, are_collinear
from solution import find_best_position, bearing, get_sorted_points

# %%
test_cases=[
    { 
        "map": """.#..#
.....
#####
....#
...##""",
        "point": (3, 4),
        "count": 8
    },
    { 
        "map": """......#.#.
#..#.#....
..#######.
.#.#.###..
.#..#.....
..#....#.#
#..#....#.
.##.#..###
##...#..#.
.#....####""",
        "point": (5, 8),
        "count": 33
    },
    { 
        "map": """#.#...#.#.
.###....#.
.#....#...
##.#.#.#.#
....#.#.#.
.##..###.#
..#...##..
..##....##
......#...
.####.###.""",
        "point": (1, 2),
        "count": 35
    },
    { 
        "map": """.#..#..###
####.###.#
....###.#.
..###.##.#
##.##.#.#.
....###..#
..#.#..#.#
#..#.#.###
.##...##.#
.....#.#..""",
        "point": (6, 3),
        "count": 41
    },
    { 
        "map": """.#..##.###...#######
##.############..##.
.#.######.########.#
.###.#######.####.#.
#####.##.#.##.###.##
..#####..#.#########
####################
#.####....###.#.#.##
##.#################
#####.##.###..####..
..######..##.#######
####.##.####...##..#
.#####..#.######.###
##...#.##########...
#.##########.#######
.####.#.###.###.#.##
....##.##.###..#####
.#.#.###########.###
#.#.#.#####.####.###
###.##.####.##.#..##""",
        "point": (11, 13),
        "count":210
    }

]

# %%
for test_case in test_cases:
    grid = Grid(test_case['map'], use_overrides=False)
    best, count, lines_by_point = find_best_position(grid)
    # print(grid)
    print(f"Best point {best} can monitor {count}")
    if best != test_case["point"]:
        print(f"Incorrect point: {best} != {test_case['point']}")
        print(len(lines_by_point[test_case['point']]))
        for line in lines_by_point[test_case['point']]:
            print(line)
    if count != test_case['count']:
        print(f"Incorrect count: {count} != {test_case['count']}")
        
    # print()
# Out:
# Best point (3, 4) can monitor 8
# Best point (5, 8) can monitor 33
# Best point (1, 2) can monitor 35
# Best point (6, 3) can monitor 41
# Best point (11, 13) can monitor 210

# %%
test_case_small = """.#....#####...#..
##...##.#####..##
##...#...#.#####.
..#.....X...###..
..#.#.....#....##"""

test_case_large = test_cases[-1]['map']

# %%
for test_case in [test_case_large]:
    grid = Grid(test_case, use_overrides=False)
    for point in grid:
        if grid.get_point(point) == 'X':
            grid.set_point(point, '#')
            break
    laser, count, lines_by_point = find_best_position(grid)
    grid.set_point(laser, 'X')
    sorted_points = get_sorted_points(lines_by_point[laser], laser)
    lines = []
    
    for idx, point in enumerate(sorted_points):
        if idx == 199:
            print(f"The {idx + 1}th asteroid to be vaporized is at {point[0]},{point[1]}.")
# Out:
# The 200th asteroid to be vaporized is at 8,2.
