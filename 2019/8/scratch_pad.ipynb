# %%
import os
import sys
sys.path.append(os.path.realpath('../..'))
import aoc
my_aoc = aoc.AdventOfCode(2019,8)

# %%
input_text = "123456789012"
width = 3
height = 2
layer_size = width * height
layers = []
for idx in range(0, len(input_text), layer_size):
    layers.append(input_text[idx:idx + layer_size])

print(layers)
# Out:
# ['123456', '789012']
