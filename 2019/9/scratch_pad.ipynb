# %%
import os
import sys
sys.path.append(os.path.realpath('../..'))
sys.path.append(os.path.realpath('..'))
import aoc
my_aoc = aoc.AdventOfCode(2019,9)
from intcode import IntCodeComputer

# %%
test_int = 1125899906842624
print(type(test_int), test_int)
# Out:
# <class 'int'> 1125899906842624

# %%
test_cases = [
    "109,1,204,-1,1001,100,1,100,1008,100,16,101,1006,101,0,99",
    #takes no input and produces a copy of itself as output.
    "1102,34915192,34915192,7,4,7,99,0",
    #should output a 16-digit number.
    "104,1125899906842624,99"
    #should output the large number in the middle.
]

for test_case in test_cases:
    output = []
    icc = IntCodeComputer(test_case)
    icc.set_output(output)
    ret_val = icc.run(0)
    print(f"{test_case} returned {ret_val}, output: {output}")
# Out:
# 109,1,204,-1,1001,100,1,100,1008,100,16,101,1006,101,0,99 returned 0, output: [109, 1, 204, -1, 1001, 100, 1, 100, 1008, 100, 16, 101, 1006, 101, 0, 99]
# 1102,34915192,34915192,7,4,7,99,0 returned 1219070632396864, output: [1219070632396864]
# 104,1125899906842624,99 returned 1125899906842624, output: [1125899906842624]
