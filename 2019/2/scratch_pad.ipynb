# %%
import os
import sys
sys.path.append(os.path.realpath('../..'))
import aoc
my_aoc = aoc.AdventOfCode(2019,2)
from solution import parse_input, execute_program

# %%
test_programs = [
    "1,9,10,3,2,3,11,0,99,30,40,50",
    "1,0,0,0,99",
    "2,3,0,3,99",
    "2,4,4,5,99,0",
    "1,1,1,4,99,5,6,0,99"
]

test_results = [
    [3500,9,10,70,2,3,11,0,99,30,40,50],
    [2,0,0,0,99],
    [2,3,0,6,99],
    [2,4,4,5,99,9801],
    [30,1,1,4,2,5,6,0,99]
]

# %%
for idx, prog_text in enumerate(test_programs):
    program = parse_input(prog_text)
    result = execute_program(list(program))
    print(f"{idx}: {program} {result} = {result == test_results[idx]}")
# Out:
# 0: [1, 9, 10, 3, 2, 3, 11, 0, 99, 30, 40, 50] [3500, 9, 10, 70, 2, 3, 11, 0, 99, 30, 40, 50] = True
# 1: [1, 0, 0, 0, 99] [2, 0, 0, 0, 99] = True
# 2: [2, 3, 0, 3, 99] [2, 3, 0, 6, 99] = True
# 3: [2, 4, 4, 5, 99, 0] [2, 4, 4, 5, 99, 9801] = True
# 4: [1, 1, 1, 4, 99, 5, 6, 0, 99] [30, 1, 1, 4, 2, 5, 6, 0, 99] = True
