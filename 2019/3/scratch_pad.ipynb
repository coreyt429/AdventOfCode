# %%
import os
import sys
sys.path.append(os.path.realpath('../..'))
import aoc
my_aoc = aoc.AdventOfCode(2019,3)
from grid import Grid, manhattan_distance
from solution import build_wires, closest_intersection, find_intersections

# %%
test_cases = []
test_cases.append(["R8,U5,L5,D3", "U7,R6,D4,L4"])
test_cases.append(["R75,D30,R83,U83,L12,D49,R71,U7,L72", "U62,R66,U55,R34,D71,R55,D58,R83"])
test_cases.append(["R98,U47,R26,D63,R33,U87,L62,D20,R33,U53,R51","U98,R91,D20,R16,D67,R40,U7,R15,U6,R7"])

# %%
for test_case in test_cases:
    result = closest_intersection(build_wires(*test_case))
    print(result)
# Out:
# 6
# 159
# 135

# %%
for test_case in test_cases:
# Out:
# 30
# 610
# 410
