# %%
import os
import sys
import functools

sys.path.append(os.path.realpath('../..'))
import aoc
my_aoc = aoc.AdventOfCode(2018,22)
from grid import Grid

# %%
# map area_types
area_type = {
    0: '.',
    1: '=',
    2: '|'
}

# reverse map to risk_level
risk_level =  {v: k for k, v in area_type.items()}

def parse_input(lines):
    depth = int(lines[0].split(' ')[1])
    target = lines[1].split(' ')[1]
    x_pos, y_pos = [int(pos) for pos in target.split(',')]
    return depth, (x_pos, y_pos)

@functools.lru_cache(maxsize=None)
def get_geologic_index(pos, depth, target):
    # print(f"get_geologic_index({pos}, {depth}, {target}):")
    # The region at 0,0 (the mouth of the cave) has a geologic index of 0.
    # The region at the coordinates of the target has a geologic index of 0.
    if pos in [(0,0), target]:
        return 0
    if pos[1] == 0:
        # If the region's Y coordinate is 0, the geologic index is its X coordinate times 16807.
        return pos[0] * 16807
    # If the region's X coordinate is 0, the geologic index is its Y coordinate times 48271.
    if pos[0] == 0:
        return pos[1] * 48271
    # Otherwise, the region's geologic index is the result of multiplying the erosion levels of the regions at X-1,Y and X,Y-1.
    return get_erosion_level((pos[0] - 1, pos[1]), depth, target) * get_erosion_level((pos[0], pos[1] - 1), depth, target)

@functools.lru_cache(maxsize=None)
def get_erosion_level(pos, depth, target):
    """
    Function to calculate erosion level for an area
    Args:
        pos: tuple() -  int(x), int(y)
        depth: int()
        target: tuple() -  int(x), int(y)
    
    Returns:
        erosion_level: int()
    """
    # A region's erosion level is its geologic index plus the cave system's depth, all modulo 20183.
    geologic_index = get_geologic_index(pos, depth, target)
    return (geologic_index + depth) % 20183

@functools.lru_cache(maxsize=None)
def get_area_type(pos, depth, target):
    """
    function to get area type
    Args:
        pos: tuple() -  int(x), int(y)
        depth: int()
        target: tuple() -  int(x), int(y)
    Returns:
        area_type: char() '.', '=', or '|'
    """
    # If the erosion level modulo 3 is 0, the region's type is rocky.
    # If the erosion level modulo 3 is 1, the region's type is wet.
    # If the erosion level modulo 3 is 2, the region's type is narrow.
    erosion_level = get_erosion_level(pos, depth, target)
    return area_type[erosion_level % 3]

def get_risk_level(grid, start, goal):
    """
    Function to calculate risk level
    Args:
        grid: Grid() current map
        start: tuple() start position x/y coordinates
        goal: tuple() end position x/y coordinates
    Returns:
        total: int() risk_level total
    """
    total = 0
    min_x = min(start[0], goal[0])
    min_y = min(start[1], goal[1])
    max_x = max(start[0], goal[0])
    max_y = max(start[1], goal[1])    
    for point in grid:
        if min_x <= point[0] <= max_x and min_y <= point[1] <= max_y:
            total += risk_level[grid.get_point(point)]
    return total

# %%
input_text = """depth: 510
target: 10,10"""
input_text = """depth: 4845
target: 6,770"""
my_grid = Grid('M', type="infinite", coordinate_system='screen', use_overrides=False)
print(my_grid)
depth, target = parse_input(input_text.splitlines())
print("test Cases:")
for point in [(0,0), (1,0), (0,1), (1,1), (10, 10)]:
    my_area_type = get_area_type(point, depth, target)
    print(f"{point}: {my_area_type}")
# Out:
# M
# test Cases:
# (0, 0): .
# (1, 0): |
# (0, 1): .
# (1, 1): =
# (10, 10): .

# %%
print(depth, target)
scale_out = 100
for x_pos in range(target[0] + scale_out):
    for y_pos in range(target[1] + scale_out):
        my_grid.set_point((x_pos, y_pos), get_area_type((x_pos, y_pos), depth, target))
my_grid.update()

risk_level = get_risk_level(my_grid, (0,0), target)
# my_grid.cfg['use_overrides'] = True
# my_grid.overrides = {
#     (0,0): 'M',
#     target: 'T'
# }
# print(my_grid)
print(f"Risk Level is {risk_level}")
# Out:
# 4845 (6, 770)
# Risk Level is 5400

# %%
from queue import PriorityQueue
from grid import manhattan_distance, Node

class ExtendedNode(Node):
    def __init__(self, *args, **kwargs):
        kwargs['skip_scoring'] = True
        super().__init__(*args, **kwargs)
        # default to torch for starting
        self.equipped = kwargs.get('equipped', 'torch')
        # get area_type from map, or calculate it if we have gone off grid
        self.area_type = self.grid.get_point(self.position)
        if self.area_type not in '.=|':
            self.area_type = get_area_type(self.position, depth, target)
        self.g_score = self.calc_g_score()
        self.h_score = self.calc_h_score()
        self.f_score = self.calc_f_score()
    
    def recalc_scores(self):
        if self.parent:
            self.parent.recalc_scores()
        self.g_score = self.calc_g_score()
        self.h_score = self.calc_h_score()
        self.f_score = self.calc_f_score()
    
    def calc_g_score(self):
        if not self.parent:
            return 0
        # Moving to an adjacent region takes one minute
        self.g_score = self.parent.g_score + 1
        # Switching to using the climbing gear, torch, or neither always takes seven minutes
        if self.equipped != self.parent.equipped:
            self.g_score += 7
        # Finally, once you reach the target, you need the torch equipped before you can find him in the dark.
        # The target is always in a rocky region, so if you arrive there with climbing gear equipped, you will
        # need to spend seven minutes switching to your torch.
        if self.position == self.goal and self.equipped != 'torch':
            self.g_score += 7
        return self.g_score
    
    def calc_f_score(self):
        return self.g_score + self.h_score
        # return float(f"{self.g_score}.{self.h_score}")
    
    def get_children(self, child_pos):
        # In rocky regions, you can use the climbing gear or the torch. You cannot use neither (you'll likely slip and fall).
        # In wet regions, you can use the climbing gear or neither tool. You cannot use the torch (if it gets wet, you won't have a light source).
        # In narrow regions, you can use the torch or neither tool. You cannot use the climbing gear (it's too bulky to fit).
        if min(child_pos) < 0:
            return []
        
        # detect loop
        if self.find_node_by_position(child_pos):
            return []
        equipment_terrain_map = {
            'climbing_gear': '.=',
            'torch': '.|',
            'neither': '=|'
        }

        terrain_equipment_map = {
            '.': ['climbing_gear', 'torch'],
            '=': ['climbing_gear', 'neither'],
            '|': ['neither', 'torch']
        }
        children  = []
        child_area_type = get_area_type(child_pos, depth, target)
        # equipment parent can use
        for equipment in terrain_equipment_map[self.area_type]:
            if equipment in terrain_equipment_map[child_area_type]:
                children.append(
                    self.__class__(
                        child_pos,
                        self.goal,
                        self,
                        grid=self.grid,
                        equipped=equipment
                    )
                )
        # if self.position[1] == 4:
        #     print(f"At {self.position}:")
        #     print(f"    self: {self.area_type} - {self.equipped} , possible: {terrain_equipment_map[self.area_type]}")
        #     print(f"    child: {child_pos} - {child_area_type} , possible: {terrain_equipment_map[child_area_type]}")        
        #     for child in children:
        #         print(f"child: {child}")
        return children
    
    def find_node_by_position(self, target):
        node = self
        while node.position != target:
            node = node.parent
            if not node:
                return None
        return node
    
    def __eq__(self, other):
        """
        Node equal
        """
        return self.position == other.position and self.equipped == other.equipped
    
    def __hash__(self):
        """
        Node Hash
        """
        return hash((self.position, self.equipped))

    def __str__(self):
        return f"""pos: {self.position}, type: {self.area_type}, equip: {self.equipped}, g_score: {self.g_score}"""
        
       
        
# # find first shortest path
# nodes = my_grid.shortest_paths((0,0), target, node_class=ExtendedNode, retval='nodes', max_paths=1)
# # The closed set in our A* algorithm can block shorter paths when there are multiple paths running
# # through the same point.
# # so lets make sure the path is optimal

# node = nodes[0]
# path = node.path()
# print(node.g_score)
# print(path)

# # for idx, start_node in enumerate(nodes):
# #     print(f"path {idx}:")
# #     node = start_node
# #     while node:
# #         print(node)
# #         node = node.parent

# %%
my_grid.update()
# print(my_grid)
import networkx

# init graph
graph = networkx.Graph()
# start with torch at (0, 0)
terrain_equipment_map = {
    '.': ['climbing_gear', 'torch'],
    '=': ['climbing_gear', 'neither'],
    '|': ['neither', 'torch']
}
for point in my_grid:
    point_terrain = my_grid.get_point(point)
    for eq_1 in terrain_equipment_map[point_terrain]:
        for eq_2 in terrain_equipment_map[point_terrain]:
            if  eq_1 == eq_2:
                continue
            # print(f"Adding edge: {(point[0], point[1], eq_1)} => {(point[0], point[1], eq_2)}")
            graph.add_edge((point[0], point[1], eq_1), (point[0], point[1], eq_2), weight=7)
for point in my_grid:
    point_terrain = my_grid.get_point(point)
    for direction, neighbor in my_grid.get_neighbors(point=point, directions=['n','e','s','w']).items():
        if direction not in ['n','e','s','w']:
            continue
        for equipped in terrain_equipment_map[point_terrain]:
            if graph.has_node((neighbor[0], neighbor[1], equipped)):
                graph.add_edge((point[0], point[1], equipped), (neighbor[0], neighbor[1], equipped), weight=1)

print("Number of nodes:", graph.number_of_nodes())
print("Number of edges:", graph.number_of_edges())

answer = networkx.dijkstra_path_length(graph, (0, 0, 'torch'), (target[0], target[1], 'torch'))
print(f"{(0,0)} to {target} = {answer}")
# Out:
# Number of nodes: 184440
# Number of edges: 337077
# (0, 0) to (6, 770) = 1048

# %%
for node in graph.nodes():
    print(node)
    break
# Out:
# (0, 0, 'climbing_gear')

# %%
networkx.dijkstra_path(graph, (0, 0, 'torch'), (target[0], target[1], 'torch'))
# Out:
# [(0, 0, 'torch'),
#  (1, 0, 'torch'),
#  (2, 0, 'torch'),
#  (3, 0, 'torch'),
#  (3, 1, 'torch'),
#  (4, 1, 'torch'),
#  (4, 2, 'torch'),
#  (4, 3, 'torch'),
#  (4, 4, 'torch'),
#  (4, 4, 'climbing_gear'),
#  (4, 5, 'climbing_gear'),
#  (4, 6, 'climbing_gear'),
#  (4, 7, 'climbing_gear'),
#  (4, 8, 'climbing_gear'),
#  (4, 9, 'climbing_gear'),
#  (4, 10, 'climbing_gear'),
#  (4, 11, 'climbing_gear'),
#  (5, 11, 'climbing_gear'),
#  (5, 12, 'climbing_gear'),
#  (5, 13, 'climbing_gear'),
#  (5, 14, 'climbing_gear'),
#  (5, 15, 'climbing_gear'),
#  (5, 16, 'climbing_gear'),
#  (5, 17, 'climbing_gear'),
#  (5, 18, 'climbing_gear'),
#  (5, 19, 'climbing_gear'),
#  (5, 20, 'climbing_gear'),
#  (5, 21, 'climbing_gear'),
#  (5, 22, 'climbing_gear'),
#  (5, 23, 'climbing_gear'),
#  (6, 23, 'climbing_gear'),
#  (6, 24, 'climbing_gear'),
#  (7, 24, 'climbing_gear'),
#  (8, 24, 'climbing_gear'),
#  (8, 25, 'climbing_gear'),
#  (8, 26, 'climbing_gear'),
#  (8, 27, 'climbing_gear'),
#  (9, 27, 'climbing_gear'),
#  (9, 28, 'climbing_gear'),
#  (9, 29, 'climbing_gear'),
#  (9, 30, 'climbing_gear'),
#  (9, 31, 'climbing_gear'),
#  (9, 32, 'climbing_gear'),
#  (9, 33, 'climbing_gear'),
#  (10, 33, 'climbing_gear'),
#  (10, 34, 'climbing_gear'),
#  (10, 35, 'climbing_gear'),
#  (10, 36, 'climbing_gear'),
#  (9, 36, 'climbing_gear'),
#  (9, 37, 'climbing_gear'),
#  (9, 38, 'climbing_gear'),
#  (9, 39, 'climbing_gear'),
#  (9, 40, 'climbing_gear'),
#  (10, 40, 'climbing_gear'),
#  (10, 41, 'climbing_gear'),
#  (11, 41, 'climbing_gear'),
#  (11, 42, 'climbing_gear'),
#  (11, 43, 'climbing_gear'),
#  (11, 44, 'climbing_gear'),
#  (11, 45, 'climbing_gear'),
#  (11, 46, 'climbing_gear'),
#  (11, 47, 'climbing_gear'),
#  (12, 47, 'climbing_gear'),
#  (12, 48, 'climbing_gear'),
#  (13, 48, 'climbing_gear'),
#  (13, 49, 'climbing_gear'),
#  (13, 50, 'climbing_gear'),
#  (13, 51, 'climbing_gear'),
#  (13, 52, 'climbing_gear'),
#  (13, 53, 'climbing_gear'),
#  (13, 54, 'climbing_gear'),
#  (13, 55, 'climbing_gear'),
#  (13, 56, 'climbing_gear'),
#  (13, 57, 'climbing_gear'),
#  (13, 58, 'climbing_gear'),
#  (13, 59, 'climbing_gear'),
#  (13, 60, 'climbing_gear'),
#  (13, 61, 'climbing_gear'),
#  (13, 62, 'climbing_gear'),
#  (14, 62, 'climbing_gear'),
#  (14, 63, 'climbing_gear'),
#  (14, 64, 'climbing_gear'),
#  (15, 64, 'climbing_gear'),
#  (16, 64, 'climbing_gear'),
#  (17, 64, 'climbing_gear'),
#  (17, 65, 'climbing_gear'),
#  (17, 66, 'climbing_gear'),
#  (18, 66, 'climbing_gear'),
#  (18, 67, 'climbing_gear'),
#  (18, 68, 'climbing_gear'),
#  (18, 69, 'climbing_gear'),
#  (18, 70, 'climbing_gear'),
#  (18, 71, 'climbing_gear'),
#  (18, 72, 'climbing_gear'),
#  (18, 73, 'climbing_gear'),
#  (18, 74, 'climbing_gear'),
#  (19, 74, 'climbing_gear'),
#  (19, 75, 'climbing_gear'),
#  (19, 76, 'climbing_gear'),
#  (19, 77, 'climbing_gear'),
#  (20, 77, 'climbing_gear'),
#  (21, 77, 'climbing_gear'),
#  (22, 77, 'climbing_gear'),
#  (22, 78, 'climbing_gear'),
#  (22, 79, 'climbing_gear'),
#  (23, 79, 'climbing_gear'),
#  (24, 79, 'climbing_gear'),
#  (24, 80, 'climbing_gear'),
#  (24, 81, 'climbing_gear'),
#  (23, 81, 'climbing_gear'),
#  (23, 82, 'climbing_gear'),
#  (23, 83, 'climbing_gear'),
#  (23, 84, 'climbing_gear'),
#  (23, 85, 'climbing_gear'),
#  (24, 85, 'climbing_gear'),
#  (24, 86, 'climbing_gear'),
#  (24, 87, 'climbing_gear'),
#  (24, 88, 'climbing_gear'),
#  (25, 88, 'climbing_gear'),
#  (25, 89, 'climbing_gear'),
#  (25, 90, 'climbing_gear'),
#  (25, 91, 'climbing_gear'),
#  (25, 92, 'climbing_gear'),
#  (25, 93, 'climbing_gear'),
#  (26, 93, 'climbing_gear'),
#  (26, 94, 'climbing_gear'),
#  (26, 95, 'climbing_gear'),
#  (26, 96, 'climbing_gear'),
#  (26, 97, 'climbing_gear'),
#  (26, 98, 'climbing_gear'),
#  (26, 99, 'climbing_gear'),
#  (26, 100, 'climbing_gear'),
#  (26, 101, 'climbing_gear'),
#  (26, 102, 'climbing_gear'),
#  (26, 103, 'climbing_gear'),
#  (26, 104, 'climbing_gear'),
#  (26, 105, 'climbing_gear'),
#  (26, 106, 'climbing_gear'),
#  (26, 107, 'climbing_gear'),
#  (26, 108, 'climbing_gear'),
#  (27, 108, 'climbing_gear'),
#  (27, 109, 'climbing_gear'),
#  (28, 109, 'climbing_gear'),
#  (28, 110, 'climbing_gear'),
#  (29, 110, 'climbing_gear'),
#  (29, 111, 'climbing_gear'),
#  (29, 112, 'climbing_gear'),
#  (29, 113, 'climbing_gear'),
#  (29, 114, 'climbing_gear'),
#  (29, 115, 'climbing_gear'),
#  (29, 116, 'climbing_gear'),
#  (30, 116, 'climbing_gear'),
#  (30, 117, 'climbing_gear'),
#  (30, 118, 'climbing_gear'),
#  (31, 118, 'climbing_gear'),
#  (31, 119, 'climbing_gear'),
#  (32, 119, 'climbing_gear'),
#  (32, 120, 'climbing_gear'),
#  (32, 121, 'climbing_gear'),
#  (32, 122, 'climbing_gear'),
#  (32, 123, 'climbing_gear'),
#  (32, 124, 'climbing_gear'),
#  (32, 125, 'climbing_gear'),
#  (31, 125, 'climbing_gear'),
#  (31, 126, 'climbing_gear'),
#  (31, 127, 'climbing_gear'),
#  (31, 128, 'climbing_gear'),
#  (31, 129, 'climbing_gear'),
#  (31, 130, 'climbing_gear'),
#  (32, 130, 'climbing_gear'),
#  (33, 130, 'climbing_gear'),
#  (33, 131, 'climbing_gear'),
#  (33, 132, 'climbing_gear'),
#  (33, 133, 'climbing_gear'),
#  (33, 134, 'climbing_gear'),
#  (34, 134, 'climbing_gear'),
#  (34, 135, 'climbing_gear'),
#  (34, 136, 'climbing_gear'),
#  (34, 137, 'climbing_gear'),
#  (35, 137, 'climbing_gear'),
#  (36, 137, 'climbing_gear'),
#  (36, 138, 'climbing_gear'),
#  (36, 139, 'climbing_gear'),
#  (37, 139, 'climbing_gear'),
#  (38, 139, 'climbing_gear'),
#  (39, 139, 'climbing_gear'),
#  (39, 140, 'climbing_gear'),
#  (39, 141, 'climbing_gear'),
#  (39, 142, 'climbing_gear'),
#  (39, 143, 'climbing_gear'),
#  (39, 144, 'climbing_gear'),
#  (39, 145, 'climbing_gear'),
#  (39, 146, 'climbing_gear'),
#  (40, 146, 'climbing_gear'),
#  (40, 147, 'climbing_gear'),
#  (41, 147, 'climbing_gear'),
#  (41, 148, 'climbing_gear'),
#  (41, 149, 'climbing_gear'),
#  (41, 150, 'climbing_gear'),
#  (41, 151, 'climbing_gear'),
#  (41, 152, 'climbing_gear'),
#  (42, 152, 'climbing_gear'),
#  (43, 152, 'climbing_gear'),
#  (43, 153, 'climbing_gear'),
#  (43, 154, 'climbing_gear'),
#  (43, 155, 'climbing_gear'),
#  (43, 156, 'climbing_gear'),
#  (43, 156, 'neither'),
#  (43, 157, 'neither'),
#  (43, 158, 'neither'),
#  (42, 158, 'neither'),
#  (42, 159, 'neither'),
#  (42, 160, 'neither'),
#  (42, 161, 'neither'),
#  (42, 162, 'neither'),
#  (42, 163, 'neither'),
#  (41, 163, 'neither'),
#  (41, 164, 'neither'),
#  (41, 165, 'neither'),
#  (41, 166, 'neither'),
#  (41, 167, 'neither'),
#  (41, 168, 'neither'),
#  (41, 169, 'neither'),
#  (41, 170, 'neither'),
#  (42, 170, 'neither'),
#  (42, 171, 'neither'),
#  (42, 172, 'neither'),
#  (43, 172, 'neither'),
#  (43, 173, 'neither'),
#  (43, 174, 'neither'),
#  (43, 175, 'neither'),
#  (43, 176, 'neither'),
#  (44, 176, 'neither'),
#  (44, 177, 'neither'),
#  (44, 178, 'neither'),
#  (44, 179, 'neither'),
#  (44, 180, 'neither'),
#  (44, 181, 'neither'),
#  (44, 182, 'neither'),
#  (44, 183, 'neither'),
#  (44, 184, 'neither'),
#  (44, 185, 'neither'),
#  (44, 186, 'neither'),
#  (44, 187, 'neither'),
#  (44, 188, 'neither'),
#  (45, 188, 'neither'),
#  (45, 189, 'neither'),
#  (46, 189, 'neither'),
#  (46, 190, 'neither'),
#  (46, 191, 'neither'),
#  (45, 191, 'neither'),
#  (44, 191, 'neither'),
#  (43, 191, 'neither'),
#  (42, 191, 'neither'),
#  (41, 191, 'neither'),
#  (41, 192, 'neither'),
#  (41, 193, 'neither'),
#  (41, 194, 'neither'),
#  (41, 195, 'neither'),
#  (41, 196, 'neither'),
#  (41, 197, 'neither'),
#  (42, 197, 'neither'),
#  (42, 198, 'neither'),
#  (42, 199, 'neither'),
#  (42, 200, 'neither'),
#  (42, 201, 'neither'),
#  (43, 201, 'neither'),
#  (44, 201, 'neither'),
#  (45, 201, 'neither'),
#  (45, 202, 'neither'),
#  (45, 203, 'neither'),
#  (45, 204, 'neither'),
#  (45, 205, 'neither'),
#  (45, 206, 'neither'),
#  (45, 207, 'neither'),
#  (45, 208, 'neither'),
#  (46, 208, 'neither'),
#  (46, 209, 'neither'),
#  (46, 210, 'neither'),
#  (47, 210, 'neither'),
#  (47, 211, 'neither'),
#  (47, 212, 'neither'),
#  (47, 213, 'neither'),
#  (47, 214, 'neither'),
#  (47, 215, 'neither'),
#  (47, 216, 'neither'),
#  (48, 216, 'neither'),
#  (49, 216, 'neither'),
#  (49, 217, 'neither'),
#  (49, 218, 'neither'),
#  (49, 219, 'neither'),
#  (48, 219, 'neither'),
#  (48, 220, 'neither'),
#  (47, 220, 'neither'),
#  (47, 221, 'neither'),
#  (47, 222, 'neither'),
#  (47, 223, 'neither'),
#  (47, 224, 'neither'),
#  (47, 225, 'neither'),
#  (47, 226, 'neither'),
#  (47, 227, 'neither'),
#  (47, 228, 'neither'),
#  (46, 228, 'neither'),
#  (46, 229, 'neither'),
#  (45, 229, 'neither'),
#  (45, 230, 'neither'),
#  (45, 231, 'neither'),
#  (45, 232, 'neither'),
#  (45, 233, 'neither'),
#  (44, 233, 'neither'),
#  (44, 234, 'neither'),
#  (44, 235, 'neither'),
#  (44, 236, 'neither'),
#  (44, 237, 'neither'),
#  (44, 238, 'neither'),
#  (44, 239, 'neither'),
#  (43, 239, 'neither'),
#  (43, 240, 'neither'),
#  (43, 241, 'neither'),
#  (43, 242, 'neither'),
#  (44, 242, 'neither'),
#  (44, 243, 'neither'),
#  (44, 244, 'neither'),
#  (44, 245, 'neither'),
#  (44, 246, 'neither'),
#  (45, 246, 'neither'),
#  (46, 246, 'neither'),
#  (46, 247, 'neither'),
#  (46, 248, 'neither'),
#  (47, 248, 'neither'),
#  (47, 249, 'neither'),
#  (47, 250, 'neither'),
#  (47, 251, 'neither'),
#  (48, 251, 'neither'),
#  (48, 252, 'neither'),
#  (49, 252, 'neither'),
#  (50, 252, 'neither'),
#  (51, 252, 'neither'),
#  (51, 253, 'neither'),
#  (51, 254, 'neither'),
#  (51, 255, 'neither'),
#  (51, 256, 'neither'),
#  (50, 256, 'neither'),
#  (50, 257, 'neither'),
#  (49, 257, 'neither'),
#  (49, 258, 'neither'),
#  (49, 259, 'neither'),
#  (49, 260, 'neither'),
#  (49, 261, 'neither'),
#  (49, 262, 'neither'),
#  (48, 262, 'neither'),
#  (48, 263, 'neither'),
#  (48, 264, 'neither'),
#  (48, 264, 'climbing_gear'),
#  (48, 265, 'climbing_gear'),
#  (48, 266, 'climbing_gear'),
#  (49, 266, 'climbing_gear'),
#  (49, 267, 'climbing_gear'),
#  (49, 268, 'climbing_gear'),
#  (49, 269, 'climbing_gear'),
#  (49, 270, 'climbing_gear'),
#  (49, 271, 'climbing_gear'),
#  (49, 272, 'climbing_gear'),
#  (49, 273, 'climbing_gear'),
#  (49, 274, 'climbing_gear'),
#  (49, 275, 'climbing_gear'),
#  (49, 276, 'climbing_gear'),
#  (49, 277, 'climbing_gear'),
#  (49, 278, 'climbing_gear'),
#  (49, 279, 'climbing_gear'),
#  (49, 280, 'climbing_gear'),
#  (49, 281, 'climbing_gear'),
#  (49, 282, 'climbing_gear'),
#  (49, 283, 'climbing_gear'),
#  (50, 283, 'climbing_gear'),
#  (50, 284, 'climbing_gear'),
#  (50, 285, 'climbing_gear'),
#  (51, 285, 'climbing_gear'),
#  (51, 286, 'climbing_gear'),
#  (51, 287, 'climbing_gear'),
#  (50, 287, 'climbing_gear'),
#  (50, 288, 'climbing_gear'),
#  (50, 289, 'climbing_gear'),
#  (50, 290, 'climbing_gear'),
#  (50, 291, 'climbing_gear'),
#  (50, 292, 'climbing_gear'),
#  (49, 292, 'climbing_gear'),
#  (49, 293, 'climbing_gear'),
#  (49, 294, 'climbing_gear'),
#  (49, 295, 'climbing_gear'),
#  (49, 296, 'climbing_gear'),
#  (50, 296, 'climbing_gear'),
#  (50, 297, 'climbing_gear'),
#  (50, 298, 'climbing_gear'),
#  (50, 299, 'climbing_gear'),
#  (51, 299, 'climbing_gear'),
#  (51, 300, 'climbing_gear'),
#  (51, 301, 'climbing_gear'),
#  (50, 301, 'climbing_gear'),
#  (50, 302, 'climbing_gear'),
#  (50, 303, 'climbing_gear'),
#  (50, 304, 'climbing_gear'),
#  (50, 305, 'climbing_gear'),
#  (50, 306, 'climbing_gear'),
#  (50, 307, 'climbing_gear'),
#  (50, 308, 'climbing_gear'),
#  (50, 309, 'climbing_gear'),
#  (50, 310, 'climbing_gear'),
#  (51, 310, 'climbing_gear'),
#  (51, 311, 'climbing_gear'),
#  (51, 312, 'climbing_gear'),
#  (51, 313, 'climbing_gear'),
#  (50, 313, 'climbing_gear'),
#  (50, 314, 'climbing_gear'),
#  (49, 314, 'climbing_gear'),
#  (49, 315, 'climbing_gear'),
#  (49, 316, 'climbing_gear'),
#  (49, 317, 'climbing_gear'),
#  (49, 318, 'climbing_gear'),
#  (48, 318, 'climbing_gear'),
#  (48, 319, 'climbing_gear'),
#  (48, 320, 'climbing_gear'),
#  (48, 321, 'climbing_gear'),
#  (49, 321, 'climbing_gear'),
#  (49, 322, 'climbing_gear'),
#  (49, 323, 'climbing_gear'),
#  (49, 324, 'climbing_gear'),
#  (50, 324, 'climbing_gear'),
#  (50, 325, 'climbing_gear'),
#  (50, 326, 'climbing_gear'),
#  (50, 327, 'climbing_gear'),
#  (50, 328, 'climbing_gear'),
#  (50, 329, 'climbing_gear'),
#  (50, 330, 'climbing_gear'),
#  (50, 331, 'climbing_gear'),
#  (50, 332, 'climbing_gear'),
#  (50, 333, 'climbing_gear'),
#  (50, 334, 'climbing_gear'),
#  (50, 335, 'climbing_gear'),
#  (50, 336, 'climbing_gear'),
#  (49, 336, 'climbing_gear'),
#  (48, 336, 'climbing_gear'),
#  (47, 336, 'climbing_gear'),
#  (47, 337, 'climbing_gear'),
#  (47, 338, 'climbing_gear'),
#  (47, 339, 'climbing_gear'),
#  (47, 340, 'climbing_gear'),
#  (47, 341, 'climbing_gear'),
#  (46, 341, 'climbing_gear'),
#  (46, 342, 'climbing_gear'),
#  (46, 343, 'climbing_gear'),
#  (45, 343, 'climbing_gear'),
#  (45, 344, 'climbing_gear'),
#  (45, 345, 'climbing_gear'),
#  (44, 345, 'climbing_gear'),
#  (44, 346, 'climbing_gear'),
#  (43, 346, 'climbing_gear'),
#  (42, 346, 'climbing_gear'),
#  (42, 347, 'climbing_gear'),
#  (41, 347, 'climbing_gear'),
#  (40, 347, 'climbing_gear'),
#  (40, 348, 'climbing_gear'),
#  (39, 348, 'climbing_gear'),
#  (39, 349, 'climbing_gear'),
#  (39, 350, 'climbing_gear'),
#  (39, 351, 'climbing_gear'),
#  (38, 351, 'climbing_gear'),
#  (38, 352, 'climbing_gear'),
#  (38, 353, 'climbing_gear'),
#  (37, 353, 'climbing_gear'),
#  (37, 354, 'climbing_gear'),
#  (37, 355, 'climbing_gear'),
#  (37, 356, 'climbing_gear'),
#  (37, 357, 'climbing_gear'),
#  (36, 357, 'climbing_gear'),
#  (35, 357, 'climbing_gear'),
#  (35, 358, 'climbing_gear'),
#  (35, 359, 'climbing_gear'),
#  (35, 360, 'climbing_gear'),
#  (35, 361, 'climbing_gear'),
#  (35, 362, 'climbing_gear'),
#  (35, 363, 'climbing_gear'),
#  (35, 364, 'climbing_gear'),
#  (35, 365, 'climbing_gear'),
#  (34, 365, 'climbing_gear'),
#  (33, 365, 'climbing_gear'),
#  (33, 366, 'climbing_gear'),
#  (33, 367, 'climbing_gear'),
#  (33, 368, 'climbing_gear'),
#  (33, 369, 'climbing_gear'),
#  (33, 370, 'climbing_gear'),
#  (33, 371, 'climbing_gear'),
#  (34, 371, 'climbing_gear'),
#  (34, 372, 'climbing_gear'),
#  (34, 373, 'climbing_gear'),
#  (34, 374, 'climbing_gear'),
#  (34, 375, 'climbing_gear'),
#  (34, 376, 'climbing_gear'),
#  (34, 377, 'climbing_gear'),
#  (34, 378, 'climbing_gear'),
#  (34, 379, 'climbing_gear'),
#  (33, 379, 'climbing_gear'),
#  (33, 380, 'climbing_gear'),
#  (33, 381, 'climbing_gear'),
#  (33, 382, 'climbing_gear'),
#  (32, 382, 'climbing_gear'),
#  (32, 383, 'climbing_gear'),
#  (32, 384, 'climbing_gear'),
#  (32, 385, 'climbing_gear'),
#  (32, 386, 'climbing_gear'),
#  (32, 387, 'climbing_gear'),
#  (32, 388, 'climbing_gear'),
#  (32, 389, 'climbing_gear'),
#  (32, 390, 'climbing_gear'),
#  (32, 391, 'climbing_gear'),
#  (32, 392, 'climbing_gear'),
#  (32, 393, 'climbing_gear'),
#  (32, 394, 'climbing_gear'),
#  (31, 394, 'climbing_gear'),
#  (31, 395, 'climbing_gear'),
#  (31, 396, 'climbing_gear'),
#  (31, 397, 'climbing_gear'),
#  (31, 398, 'climbing_gear'),
#  (31, 399, 'climbing_gear'),
#  (31, 400, 'climbing_gear'),
#  (31, 400, 'torch'),
#  (31, 401, 'torch'),
#  (30, 401, 'torch'),
#  (30, 402, 'torch'),
#  (30, 403, 'torch'),
#  (30, 404, 'torch'),
#  (29, 404, 'torch'),
#  (29, 405, 'torch'),
#  (29, 406, 'torch'),
#  (29, 407, 'torch'),
#  (29, 408, 'torch'),
#  (29, 409, 'torch'),
#  (28, 409, 'torch'),
#  (28, 410, 'torch'),
#  (27, 410, 'torch'),
#  (27, 411, 'torch'),
#  (27, 412, 'torch'),
#  (27, 413, 'torch'),
#  (27, 414, 'torch'),
#  (27, 415, 'torch'),
#  (27, 416, 'torch'),
#  (27, 417, 'torch'),
#  (26, 417, 'torch'),
#  (26, 418, 'torch'),
#  (26, 419, 'torch'),
#  (26, 420, 'torch'),
#  (25, 420, 'torch'),
#  (25, 421, 'torch'),
#  (25, 422, 'torch'),
#  (26, 422, 'torch'),
#  (26, 423, 'torch'),
#  (26, 424, 'torch'),
#  (26, 425, 'torch'),
#  (25, 425, 'torch'),
#  (25, 426, 'torch'),
#  (25, 427, 'torch'),
#  (25, 428, 'torch'),
#  (25, 429, 'torch'),
#  (24, 429, 'torch'),
#  (23, 429, 'torch'),
#  (23, 430, 'torch'),
#  (23, 431, 'torch'),
#  (23, 432, 'torch'),
#  (23, 433, 'torch'),
#  (23, 434, 'torch'),
#  (23, 435, 'torch'),
#  (23, 436, 'torch'),
#  (23, 437, 'torch'),
#  (22, 437, 'torch'),
#  (21, 437, 'torch'),
#  (21, 438, 'torch'),
#  (21, 439, 'torch'),
#  (21, 440, 'torch'),
#  (21, 441, 'torch'),
#  (21, 442, 'torch'),
#  (21, 443, 'torch'),
#  (21, 444, 'torch'),
#  (22, 444, 'torch'),
#  (22, 445, 'torch'),
#  (23, 445, 'torch'),
#  (23, 446, 'torch'),
#  (23, 447, 'torch'),
#  (24, 447, 'torch'),
#  (24, 448, 'torch'),
#  (24, 449, 'torch'),
#  (24, 450, 'torch'),
#  (25, 450, 'torch'),
#  (25, 451, 'torch'),
#  (25, 452, 'torch'),
#  (25, 453, 'torch'),
#  (25, 454, 'torch'),
#  (25, 455, 'torch'),
#  (25, 456, 'torch'),
#  (25, 457, 'torch'),
#  (25, 458, 'torch'),
#  (25, 459, 'torch'),
#  (25, 460, 'torch'),
#  (25, 461, 'torch'),
#  (25, 462, 'torch'),
#  (25, 463, 'torch'),
#  (24, 463, 'torch'),
#  (24, 464, 'torch'),
#  (24, 465, 'torch'),
#  (25, 465, 'torch'),
#  (25, 466, 'torch'),
#  (26, 466, 'torch'),
#  (26, 467, 'torch'),
#  (27, 467, 'torch'),
#  (27, 468, 'torch'),
#  (28, 468, 'torch'),
#  (28, 469, 'torch'),
#  (28, 470, 'torch'),
#  (28, 471, 'torch'),
#  (29, 471, 'torch'),
#  (29, 472, 'torch'),
#  (29, 473, 'torch'),
#  (28, 473, 'torch'),
#  (28, 474, 'torch'),
#  (28, 475, 'torch'),
#  (27, 475, 'torch'),
#  (26, 475, 'torch'),
#  (25, 475, 'torch'),
#  (25, 476, 'torch'),
#  (25, 477, 'torch'),
#  (25, 478, 'torch'),
#  (24, 478, 'torch'),
#  (24, 479, 'torch'),
#  (23, 479, 'torch'),
#  (23, 480, 'torch'),
#  (23, 481, 'torch'),
#  (23, 482, 'torch'),
#  (23, 483, 'torch'),
#  (23, 484, 'torch'),
#  (22, 484, 'torch'),
#  (22, 485, 'torch'),
#  (22, 486, 'torch'),
#  (22, 487, 'torch'),
#  (21, 487, 'torch'),
#  (21, 488, 'torch'),
#  (21, 489, 'torch'),
#  (21, 490, 'torch'),
#  (20, 490, 'torch'),
#  (20, 491, 'torch'),
#  (20, 492, 'torch'),
#  (20, 493, 'torch'),
#  (20, 494, 'torch'),
#  (20, 495, 'torch'),
#  (20, 496, 'torch'),
#  (19, 496, 'torch'),
#  (18, 496, 'torch'),
#  (18, 497, 'torch'),
#  (18, 498, 'torch'),
#  (18, 499, 'torch'),
#  (18, 500, 'torch'),
#  (17, 500, 'torch'),
#  (17, 501, 'torch'),
#  (17, 502, 'torch'),
#  (17, 503, 'torch'),
#  (17, 504, 'torch'),
#  (17, 505, 'torch'),
#  (17, 506, 'torch'),
#  (18, 506, 'torch'),
#  (18, 507, 'torch'),
#  (18, 508, 'torch'),
#  (18, 509, 'torch'),
#  (17, 509, 'torch'),
#  (16, 509, 'torch'),
#  (16, 510, 'torch'),
#  (16, 511, 'torch'),
#  (16, 512, 'torch'),
#  (15, 512, 'torch'),
#  (15, 513, 'torch'),
#  (15, 514, 'torch'),
#  (15, 515, 'torch'),
#  (15, 516, 'torch'),
#  (15, 517, 'torch'),
#  (14, 517, 'torch'),
#  (14, 518, 'torch'),
#  (14, 519, 'torch'),
#  (15, 519, 'torch'),
#  (15, 520, 'torch'),
#  (15, 521, 'torch'),
#  (15, 522, 'torch'),
#  (15, 523, 'torch'),
#  (14, 523, 'torch'),
#  (13, 523, 'torch'),
#  (13, 524, 'torch'),
#  (13, 525, 'torch'),
#  (13, 526, 'torch'),
#  (13, 527, 'torch'),
#  (14, 527, 'torch'),
#  (15, 527, 'torch'),
#  (15, 528, 'torch'),
#  (15, 529, 'torch'),
#  (15, 530, 'torch'),
#  (15, 531, 'torch'),
#  (15, 532, 'torch'),
#  (15, 533, 'torch'),
#  (15, 534, 'torch'),
#  (15, 535, 'torch'),
#  (15, 536, 'torch'),
#  (16, 536, 'torch'),
#  (16, 537, 'torch'),
#  (17, 537, 'torch'),
#  (18, 537, 'torch'),
#  (18, 538, 'torch'),
#  (18, 539, 'torch'),
#  (18, 540, 'torch'),
#  (18, 541, 'torch'),
#  (19, 541, 'torch'),
#  (19, 542, 'torch'),
#  (19, 543, 'torch'),
#  (19, 544, 'torch'),
#  (18, 544, 'torch'),
#  (18, 545, 'torch'),
#  (18, 546, 'torch'),
#  (17, 546, 'torch'),
#  (17, 547, 'torch'),
#  (16, 547, 'torch'),
#  (16, 548, 'torch'),
#  (16, 549, 'torch'),
#  (16, 550, 'torch'),
#  (16, 551, 'torch'),
#  (15, 551, 'torch'),
#  (15, 552, 'torch'),
#  (15, 553, 'torch'),
#  (15, 554, 'torch'),
#  (15, 555, 'torch'),
#  (15, 556, 'torch'),
#  (14, 556, 'torch'),
#  (14, 557, 'torch'),
#  (14, 558, 'torch'),
#  (14, 559, 'torch'),
#  (14, 560, 'torch'),
#  (14, 561, 'torch'),
#  (13, 561, 'torch'),
#  (13, 562, 'torch'),
#  (13, 563, 'torch'),
#  (13, 564, 'torch'),
#  (13, 565, 'torch'),
#  (13, 566, 'torch'),
#  (14, 566, 'torch'),
#  (14, 567, 'torch'),
#  (15, 567, 'torch'),
#  (15, 568, 'torch'),
#  (16, 568, 'torch'),
#  (17, 568, 'torch'),
#  (17, 569, 'torch'),
#  (17, 570, 'torch'),
#  (17, 571, 'torch'),
#  (16, 571, 'torch'),
#  (16, 572, 'torch'),
#  (15, 572, 'torch'),
#  (14, 572, 'torch'),
#  (14, 573, 'torch'),
#  (13, 573, 'torch'),
#  (13, 574, 'torch'),
#  (13, 575, 'torch'),
#  (13, 576, 'torch'),
#  (12, 576, 'torch'),
#  (12, 577, 'torch'),
#  (11, 577, 'torch'),
#  (10, 577, 'torch'),
#  (10, 578, 'torch'),
#  (10, 579, 'torch'),
#  (10, 580, 'torch'),
#  (10, 581, 'torch'),
#  (10, 582, 'torch'),
#  (10, 583, 'torch'),
#  (10, 584, 'torch'),
#  (10, 585, 'torch'),
#  (10, 586, 'torch'),
#  (10, 587, 'torch'),
#  (10, 588, 'torch'),
#  (10, 589, 'torch'),
#  (10, 590, 'torch'),
#  (10, 591, 'torch'),
#  (10, 592, 'torch'),
#  (10, 593, 'torch'),
#  (10, 594, 'torch'),
#  (9, 594, 'torch'),
#  (9, 595, 'torch'),
#  (9, 596, 'torch'),
#  (10, 596, 'torch'),
#  (10, 597, 'torch'),
#  (10, 598, 'torch'),
#  (10, 599, 'torch'),
#  (10, 600, 'torch'),
#  (10, 601, 'torch'),
#  (10, 602, 'torch'),
#  (10, 603, 'torch'),
#  (10, 604, 'torch'),
#  (11, 604, 'torch'),
#  (12, 604, 'torch'),
#  (12, 605, 'torch'),
#  (12, 606, 'torch'),
#  (12, 607, 'torch'),
#  (12, 608, 'torch'),
#  (12, 609, 'torch'),
#  (12, 610, 'torch'),
#  (12, 611, 'torch'),
#  (13, 611, 'torch'),
#  (13, 612, 'torch'),
#  (14, 612, 'torch'),
#  (14, 613, 'torch'),
#  (14, 614, 'torch'),
#  (14, 615, 'torch'),
#  (13, 615, 'torch'),
#  (13, 616, 'torch'),
#  (13, 617, 'torch'),
#  (13, 618, 'torch'),
#  (12, 618, 'torch'),
#  (11, 618, 'torch'),
#  (10, 618, 'torch'),
#  (9, 618, 'torch'),
#  (9, 619, 'torch'),
#  (9, 620, 'torch'),
#  (8, 620, 'torch'),
#  (8, 621, 'torch'),
#  (8, 622, 'torch'),
#  (8, 623, 'torch'),
#  (8, 624, 'torch'),
#  (8, 625, 'torch'),
#  (8, 626, 'torch'),
#  (8, 627, 'torch'),
#  (7, 627, 'torch'),
#  (6, 627, 'torch'),
#  (5, 627, 'torch'),
#  (4, 627, 'torch'),
#  (4, 628, 'torch'),
#  (3, 628, 'torch'),
#  (2, 628, 'torch'),
#  (2, 629, 'torch'),
#  (2, 630, 'torch'),
#  (2, 631, 'torch'),
#  (2, 632, 'torch'),
#  (2, 633, 'torch'),
#  (2, 634, 'torch'),
#  (2, 635, 'torch'),
#  (2, 636, 'torch'),
#  (2, 637, 'torch'),
#  (2, 638, 'torch'),
#  (2, 639, 'torch'),
#  (2, 640, 'torch'),
#  (3, 640, 'torch'),
#  (3, 641, 'torch'),
#  (3, 642, 'torch'),
#  (4, 642, 'torch'),
#  (4, 643, 'torch'),
#  (4, 644, 'torch'),
#  (4, 645, 'torch'),
#  (5, 645, 'torch'),
#  (5, 646, 'torch'),
#  (5, 647, 'torch'),
#  (5, 648, 'torch'),
#  (6, 648, 'torch'),
#  (7, 648, 'torch'),
#  (7, 649, 'torch'),
#  (7, 650, 'torch'),
#  (7, 651, 'torch'),
#  (7, 652, 'torch'),
#  (7, 653, 'torch'),
#  (7, 654, 'torch'),
#  (7, 655, 'torch'),
#  (7, 656, 'torch'),
#  (7, 657, 'torch'),
#  (7, 658, 'torch'),
#  (7, 659, 'torch'),
#  (6, 659, 'torch'),
#  (5, 659, 'torch'),
#  (5, 660, 'torch'),
#  (5, 661, 'torch'),
#  (6, 661, 'torch'),
#  (6, 662, 'torch'),
#  (7, 662, 'torch'),
#  (8, 662, 'torch'),
#  (8, 663, 'torch'),
#  (8, 664, 'torch'),
#  (8, 665, 'torch'),
#  (8, 666, 'torch'),
#  (8, 667, 'torch'),
#  (8, 668, 'torch'),
#  (7, 668, 'torch'),
#  (7, 669, 'torch'),
#  (6, 669, 'torch'),
#  (6, 670, 'torch'),
#  (5, 670, 'torch'),
#  (5, 671, 'torch'),
#  (5, 672, 'torch'),
#  (5, 673, 'torch'),
#  (5, 674, 'torch'),
#  (6, 674, 'torch'),
#  (6, 675, 'torch'),
#  (6, 676, 'torch'),
#  (6, 677, 'torch'),
#  (6, 678, 'torch'),
#  (6, 679, 'torch'),
#  (6, 680, 'torch'),
#  (5, 680, 'torch'),
#  (4, 680, 'torch'),
#  (4, 681, 'torch'),
#  (4, 682, 'torch'),
#  (5, 682, 'torch'),
#  (5, 683, 'torch'),
#  (5, 684, 'torch'),
#  (5, 685, 'torch'),
#  (5, 686, 'torch'),
#  (5, 687, 'torch'),
#  (5, 688, 'torch'),
#  (6, 688, 'torch'),
#  (6, 689, 'torch'),
#  (6, 690, 'torch'),
#  (7, 690, 'torch'),
#  (8, 690, 'torch'),
#  (8, 691, 'torch'),
#  (9, 691, 'torch'),
#  (9, 692, 'torch'),
#  (9, 693, 'torch'),
#  (9, 694, 'torch'),
#  (9, 695, 'torch'),
#  (9, 696, 'torch'),
#  (10, 696, 'torch'),
#  (10, 697, 'torch'),
#  (11, 697, 'torch'),
#  (12, 697, 'torch'),
#  (12, 698, 'torch'),
#  (12, 699, 'torch'),
#  (12, 700, 'torch'),
#  (12, 701, 'torch'),
#  (11, 701, 'torch'),
#  (11, 702, 'torch'),
#  (11, 703, 'torch'),
#  (11, 704, 'torch'),
#  (11, 705, 'torch'),
#  (11, 706, 'torch'),
#  (12, 706, 'torch'),
#  (12, 707, 'torch'),
#  (12, 708, 'torch'),
#  (12, 709, 'torch'),
#  (12, 710, 'torch'),
#  (12, 711, 'torch'),
#  (12, 712, 'torch'),
#  (12, 713, 'torch'),
#  (12, 714, 'torch'),
#  (12, 715, 'torch'),
#  (12, 716, 'torch'),
#  (12, 717, 'torch'),
#  (12, 718, 'torch'),
#  (12, 719, 'torch'),
#  (11, 719, 'torch'),
#  (11, 720, 'torch'),
#  (11, 721, 'torch'),
#  (11, 722, 'torch'),
#  (11, 723, 'torch'),
#  (11, 724, 'torch'),
#  (11, 725, 'torch'),
#  (11, 726, 'torch'),
#  (11, 727, 'torch'),
#  (12, 727, 'torch'),
#  (13, 727, 'torch'),
#  (13, 728, 'torch'),
#  (14, 728, 'torch'),
#  (15, 728, 'torch'),
#  (15, 729, 'torch'),
#  (15, 730, 'torch'),
#  (15, 731, 'torch'),
#  (15, 732, 'torch'),
#  (15, 733, 'torch'),
#  (14, 733, 'torch'),
#  (13, 733, 'torch'),
#  (12, 733, 'torch'),
#  (11, 733, 'torch'),
#  (11, 734, 'torch'),
#  (10, 734, 'torch'),
#  (10, 735, 'torch'),
#  (10, 736, 'torch'),
#  (10, 737, 'torch'),
#  (10, 738, 'torch'),
#  (10, 739, 'torch'),
#  (10, 740, 'torch'),
#  (10, 741, 'torch'),
#  (9, 741, 'torch'),
#  (9, 742, 'torch'),
#  (9, 743, 'torch'),
#  (9, 744, 'torch'),
#  (9, 745, 'torch'),
#  (9, 746, 'torch'),
#  (9, 747, 'torch'),
#  (9, 748, 'torch'),
#  (9, 749, 'torch'),
#  (9, 750, 'torch'),
#  (8, 750, 'torch'),
#  (8, 751, 'torch'),
#  (8, 752, 'torch'),
#  (8, 753, 'torch'),
#  ...]

# %%
for node in graph.nodes:
    if node[0] == 0 and node[1] == 0:
        print(node)
# Out:
# (0, 0, 'climbing_gear')
# (0, 0, 'torch')
