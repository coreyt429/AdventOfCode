# %%
import os
import sys
sys.path.append(os.path.realpath('../..'))
import aoc
my_aoc = aoc.AdventOfCode(2020,10)

# %%
input_text = """28
33
18
42
31
14
46
20
48
47
24
23
49
45
19
38
39
11
1
32
25
35
8
17
7
9
4
2
34
10
3"""

# %%
numbers = [int(num) for num in input_text.splitlines()] + [0]
sorted_numbers = sorted(numbers)
sorted_numbers.append(sorted_numbers[-1]+3)
print(sorted_numbers)
# Out:
# [0, 1, 2, 3, 4, 7, 8, 9, 10, 11, 14, 17, 18, 19, 20, 23, 24, 25, 28, 31, 32, 33, 34, 35, 38, 39, 42, 45, 46, 47, 48, 49, 52]

# %%
from collections import defaultdict
jolt_differences = defaultdict(int)
for idx, num in enumerate(sorted_numbers):
    if num == sorted_numbers[-1]:
        continue
    diff = sorted_numbers[idx + 1] - num
    jolt_differences[diff] += 1
print(jolt_differences)
# Out:
# defaultdict(<class 'int'>, {1: 22, 3: 10})

# %%
def depth_first_counter(dag, current_jolt, memoization={}):
    if current_jolt in memoization:
        return memoization[current_jolt]
    if dag[current_jolt]:
        memoization[current_jolt] = sum(
            depth_first_counter(dag, next_jolt, ) for next_jolt in dag[current_jolt]
        )
        return memoization[current_jolt]
    return 1

dag = dict(
    [
        (x, 
         {y for y in range(x+1, x+4) if y in sorted_numbers}) for x in sorted_numbers
    ]
)

print(depth_first_counter(dag, 0))
# Out:
# 19208
