# %%
import os
import sys
sys.path.append(os.path.realpath('../..'))
import aoc
my_aoc = aoc.AdventOfCode(2020,1)

# %%
input_text = """1721
979
366
299
675
1456"""

numbers = [int(line) for line in input_text.splitlines()]
print(numbers)
# Out:
# [1721, 979, 366, 299, 675, 1456]

# %%
from itertools import combinations

for num_a, num_b in combinations(numbers, 2):
    if num_a + num_b == 2020:
        print({num_a * num_b})
        break
# Out:
# {514579}
