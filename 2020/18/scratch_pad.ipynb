# %%
import os
import sys
sys.path.append(os.path.realpath('../..'))
import aoc
my_aoc = aoc.AdventOfCode(2020,18)
from solution import simplify_expression, simplify_addition

# %%
           

expressions = [
    '1 + 2 * 3 + 4 * 5 + 6',
    '1 + (2 * 3) + (4 * (5 + 6))',
    '2 * 3 + (4 * 5)',
    '5 + (8 * 3 + 9 + 3 * 4 * 3)',
    '5 * 9 * (7 * 3 * 3 + 9 * 3 + (8 + 6 * 4))',
    '((2 + 4 * 9) * (6 + 9 * 8 + 6) + 6) + 2 + 4 * 2'
]
for expression in expressions:
    print(f"{expression} = {simplify_expression(expression)}")
    print(f"{expression} = {simplify_expression(expression, 2)}")
    

import re
# Out:
# 1 + 2 * 3 + 4 * 5 + 6 = 71
# 1 + 2 * 3 + 4 * 5 + 6 = 231
# 1 + (2 * 3) + (4 * (5 + 6)) = 51
# 1 + (2 * 3) + (4 * (5 + 6)) = 51
# 2 * 3 + (4 * 5) = 26
# 2 * 3 + (4 * 5) = 46
# 5 + (8 * 3 + 9 + 3 * 4 * 3) = 437
# 5 + (8 * 3 + 9 + 3 * 4 * 3) = 1445
# 5 * 9 * (7 * 3 * 3 + 9 * 3 + (8 + 6 * 4)) = 12240
# 5 * 9 * (7 * 3 * 3 + 9 * 3 + (8 + 6 * 4)) = 669060
# ((2 + 4 * 9) * (6 + 9 * 8 + 6) + 6) + 2 + 4 * 2 = 13632
# ((2 + 4 * 9) * (6 + 9 * 8 + 6) + 6) + 2 + 4 * 2 = 23340

# %%
def simplify_expression_orig(exp_string, part=1):
    """
    Function to simplify expression string
    """
    # print(f"simplify_expression({exp_string})")
    while '+' in exp_string or '*' in exp_string:
        matches = pattern_group.findall(exp_string)
        if matches:
            for match in matches:
                # print(f"match: {match}")
                exp_string = exp_string.replace(f"({match})", simplify_expression(match, part))
        else:
            total = 0
            operand=''
            operators = {
                '+': operator.iadd,
                '*': operator.imul
            }
            op = None
            for char in exp_string:
                # print(f"char: {char}, total: {total}, operand: {operand}, op {op}")
                if char.isdigit():
                    operand += char
                elif char in operators:
                    if total == 0:
                        total = int(operand)
                    else:
                        total = operators[op](total, int(operand))
                    op = char
                    operand=''
                elif char == ' ':
                    pass
                else:
                    print(f"invalid expression: {exp_string}")
            if op in operators:
                if total == 0:
                    total = int(operand)
                else:
                    # print(f"test: {total}{op}{operand}={operators[op](total, int(operand))}")
                    total = operators[op](total, int(operand))
                    op = char
            exp_string = str(total)
    return exp_string

# %%
import re
pattern_addition = re.compile(r'(\d+ \+ \d+)')


match = pattern_addition.fullmatch('1 * 4 + 5')

if match:
    print(match)
else:
    print('no')
# Out:
# no

# %%
answer = simplify_expression('8 + 9 + 7 + 7 + ((5 + 8 * 8 + 5) * (8 * 4 + 9 + 4) + 9)', 2)
print(answer)
# Out:
# 24536

# %%
simplify_addition('8 + 9 + 7 + 7, 2', 2)
# Out:
# '17 + 7 + 7, 2'

# %%
simplify_expression('8 + 9', 2)
# Out:
# '17'
