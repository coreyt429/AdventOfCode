# %%
import os
import sys
sys.path.append(os.path.realpath('../..'))
import aoc
my_aoc = aoc.AdventOfCode(2020,14)
from solution import apply_mask, build_mask, mask_as_string, mask_address

# %%
from collections import defaultdict
import re

# %%
input_text = """mask = XXXXXXXXXXXXXXXXXXXXXXXXXXXXX1XXXX0X
mem[8] = 11
mem[7] = 101
mem[8] = 0"""

# The entire 36-bit address space begins initialized to the value 0 at every address.
memory=defaultdict(int)
mask_str, *instructions = input_text.splitlines()
mask = build_mask(mask_str)


print(mask)
print(instructions)
print(memory)
# Out:
# {29: 1, 34: 0}
# ['mem[8] = 11', 'mem[7] = 101', 'mem[8] = 0']
# defaultdict(<class 'int'>, {})

# %%
pattern_instruction = re.compile(r'(\d+)')
for instruction in instructions:
    matches = pattern_instruction.findall(instruction)
    address = int(matches.pop(0))
    value = int(matches.pop(0))
    memory[address] = apply_mask(value, mask)
print(sum(memory.values()))
# Out:
# 165

# %%
a = ['X',0,'X',1]
print(str(a))
# Out:
# ['X', 0, 'X', 1]

# %%
input_text = """mask = 000000000000000000000000000000X1001X
mem[42] = 100
mask = 00000000000000000000000000000000X0XX
mem[26] = 1"""
memory=defaultdict(int)

pattern_instruction = re.compile(r'(\d+)')
for instruction in input_text.splitlines():
    if "mask" in instruction:
            mask = build_mask(instruction, 2)
            # hey, we shouldn't process any more from here, bad things happen
            continue
    matches = pattern_instruction.findall(instruction)
    address = int(matches.pop(0))
    value = int(matches.pop(0))
    for addr in mask_address(address, mask):
        # print(f"addr: {addr}, value: {value}")
        memory[addr] = value
print(sum(memory.values()))
# Out:
# 208
