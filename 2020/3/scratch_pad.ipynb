# %%
import os
import sys
sys.path.append(os.path.realpath('../..'))
import aoc
my_aoc = aoc.AdventOfCode(2020,3)

# %%
from grid import Grid
input_text = """..##.......
#...#...#..
.#....#..#.
..#.#...#.#
.#...##..#.
..#.##.....
.#.#.#....#
.#........#
#.##...#...
#...##....#
.#..#...#.#"""

grid = Grid(input_text, use_overrides=False)
slope = (3, 1)
x_val = 3
my_string = ''
for y_val in range(grid.cfg["max"][1]):
    my_string  += grid.get_point(point=(x_val, y_val))
    x_val = (x_val + slope[0]) % grid.cfg["max"][0]

print(my_string.count('#'))
# Out:
# 7
